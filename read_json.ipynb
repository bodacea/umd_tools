# %% [markdown]
# # Read a json file
#
# Json is "the one with the curly brackets"
# Many programs - and especially APIs - output json formatted data
#
# Good articles on json include https://realpython.com/python-json/
#
# Python libraries and functions in them include:
# * Library json, functions load, loads
# * Library pandas, functions read_json, json_normalize

# %%
# load in the libraries you need, and point at your json file
import json
import pandas as pd

jsonroot = 'data/smat_outputs/response_1634667265142'
jsonfile = jsonroot + '.json'

# %%
# read the file with library json
with open(jsonfile, "r") as read_file:
    jsondata = json.load(read_file)

jsondata
# Out:
# {'created_key': 'now',
#  'content_key': 'htmlparsedcom',
#  'took': 1108,
#  'timed_out': False,
#  '_shards': {'total': 2, 'successful': 2, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 9, 'relation': 'eq'},
#   'max_score': None,
#   'hits': [{'_index': 'smat-4chan-data-000002',
#     '_type': '_doc',
#     '_id': 'news_941273',
#     '_score': None,
#     '_ignored': ['htmlparsedcom.keyword', 'com.keyword'],
#     '_source': {'board': 'news',
#      'chan': 1,
#      'id': 560000941273,
#      'urls': [],
#      'v': 1.7,
#      'com': 'Investigating the attack — which resulted in injuries to more than 150 police officers — is a key priority for Congressional Democrats.<br><br>Trump’s move could also create a dilemma for the Biden administration. Most presidents are loath to weaken executive privilege, the vaguely defined right for presidents to have conversations with their advisers without worrying those conversations may someday become public.<br><br>The Constitution does not mention the concept, but the courts have held it exists. Presidents sometimes assert it to shield their advisers from compliance with congressional subpoenas.<br><br>The White House clarified its stance on assertion of executive privilege regarding the Jan. 6 committee’s requests last month after press secretary Jen Psaki said a decision was made to not shield any Trump-era records. Following that Psaki comment, a White House spokesperson said the Biden administration would actually make those calls on a “case-by-case” basis.<br><br>Nonetheless, experts previously told POLITICO that they suspect Biden’s White House counsel’s office may assert privilege on Trump’s behalf in some cases. That’s because weakening executive privilege broadly could create problems for Biden down the road. The subpoena of Meadows is particularly sensitive; the idea of congressional investigators from the opposing party grilling a White House chief of staff is a nightmare scenario for most presidents. <br><br>At the same time, Meadows likely has detailed knowledge of Trump’s behavior before and during the Jan. 6 attack and was backstage at the #StopTheSteal rally on the National Mall where Trump spoke before the Capitol siege.<br><br>Experts are divided over the question of how former presidents can wield executive privilege. David Rivkin, formerly a lawyer for the Ronald Reagan and George H. W. Bush administrations, told POLITICO that only sitting presidents can assert executive privilege.',
#      'htmlparsedcom': 'Investigating the attack — which resulted in injuries to more than 150 police officers — is a key priority for Congressional Democrats.Trump’s move could also create a dilemma for the Biden administration. Most presidents are loath to weaken executive privilege, the vaguely defined right for presidents to have conversations with their advisers without worrying those conversations may someday become public.The Constitution does not mention the concept, but the courts have held it exists. Presidents sometimes assert it to shield their advisers from compliance with congressional subpoenas.The White House clarified its stance on assertion of executive privilege regarding the Jan. 6 committee’s requests last month after press secretary Jen Psaki said a decision was made to not shield any Trump-era records. Following that Psaki comment, a White House spokesperson said the Biden administration would actually make those calls on a “case-by-case” basis.Nonetheless, experts previously told POLITICO that they suspect Biden’s White House counsel’s office may assert privilege on Trump’s behalf in some cases. That’s because weakening executive privilege broadly could create problems for Biden down the road. The subpoena of Meadows is particularly sensitive; the idea of congressional investigators from the opposing party grilling a White House chief of staff is a nightmare scenario for most presidents. At the same time, Meadows likely has detailed knowledge of Trump’s behavior before and during the Jan. 6 attack and was backstage at the #StopTheSteal rally on the National Mall where Trump spoke before the Capitol siege.Experts are divided over the question of how former presidents can wield executive privilege. David Rivkin, formerly a lawyer for the Ronald Reagan and George H. W. Bush administrations, told POLITICO that only sitting presidents can assert executive privilege.',
#      'name': 'Anonymous',
#      'no': 941273,
#      'now': '10/07/21(Thu)18:35:57',
#      'resto': 941269,
#      'time': 1633646157,
#      'archivedon': 1634664158.109893},
#     'sort': [1633631757000]},
#    {'_index': 'smat-4chan-data-000002',
#     '_type': '_doc',
#     '_id': 'tv_157006540',
#     '_score': None,
#     '_source': {'board': 'tv',
#      'chan': 1,
#      'id': 670000157006540,
#      'urls': [],
#      'v': 1.7,
#      'com': '<a href="#p157006406" class="quotelink">&gt;&gt;157006406</a><br><span class="quote">&gt;fraud of 2020 election</span><br>lol<br>don&#039;t forget to donate to #stopthesteal!',
#      'htmlparsedcom': ">>157006406>fraud of 2020 electionloldon't forget to donate to #stopthesteal!",
#      'name': 'Anonymous',
#      'no': 157006540,
#      'now': '09/30/21(Thu)11:56:22',
#      'resto': 157001121,
#      'time': 1633017382,
#      'archivedon': 1633017554.681834},
#     'sort': [1633002982000]},
#    {'_index': 'smat-4chan-data-000001',
#     '_type': '_doc',
#     '_id': 'sp_113574173',
#     '_score': None,
#     '_source': {'board': 'sp',
#      'chan': 1,
#      'id': 630000113574173,
#      'urls': [],
#      'v': 1.7,
#      'com': '#stopthesteal',
#      'country': 'AU',
#      'countryname': 'Australia',
#      'htmlparsedcom': '#stopthesteal',
#      'name': 'Anonymous',
#      'no': 113574173,
#      'now': '09/25/21(Sat)07:46:51',
#      'resto': 113573587,
#      'time': 1632570411,
#      'archivedon': 1632570566.413973},
#     'sort': [1632556011000]},
#    {'_index': 'smat-4chan-data-000001',
#     '_type': '_doc',
#     '_id': 'pol_340727489',
#     '_score': None,
#     '_source': {'board': 'pol',
#      'chan': 1,
#      'id': 'agF8ZtES',
#      'urls': ['https://i.4cdn.org/pol/1632527327341.jpg'],
#      'v': 1.7,
#      'com': '<a href="#p340723135" class="quotelink">&gt;&gt;340723135</a><br>Make sure to keep donating, paypiggy!<br>#stopthesteal',
#      'country': 'US',
#      'countryname': 'United States',
#      'ext': '.jpg',
#      'filename': '1632527319122',
#      'fsize': 113267,
#      'h': 1280,
#      'htmlparsedcom': '>>340723135Make sure to keep donating, paypiggy!#stopthesteal',
#      'mimg': 1,
#      'md5': 'iiW4jL9s7LJhBJmwjYgttQ==',
#      'name': 'Anonymous',
#      'no': 340727489,
#      'now': '09/24/21(Fri)19:48:47',
#      'resto': 340723135,
#      'tim': 1632527327341,
#      'time': 1632527327,
#      'tnh': 125,
#      'tnw': 57,
#      'w': 591,
#      'archivedon': 1632527355.905724},
#     'sort': [1632512927000]},
#    {'_index': 'smat-4chan-data-000001',
#     '_type': '_doc',
#     '_id': 'pol_339658457',
#     '_score': None,
#     '_ignored': ['htmlparsedcom.keyword', 'com.keyword'],
#     '_source': {'board': 'pol',
#      'chan': 1,
#      'id': 'xs/Q8Mvw',
#      'urls': [],
#      'v': 1.7,
#      'com': '<a href="#p339657365" class="quotelink">&gt;&gt;339657365</a><br><span class="quote">&gt;&gt;hes dommed by a paki gay credit card scammer lol.</span><br><span class="quote">&gt;?</span><br>ali akbar drug nick around for #STOPTHESTEAL and nick stood behind him like a kid behind his mom<br><br>ali akbar is a literal gay MAP who got arrested for stealing credit cards lol. nick fuentes fucking sucks. but hes relatable to alot of people on pol so he stays around.',
#      'country': 'US',
#      'countryname': 'United States',
#      'htmlparsedcom': '>>339657365>>hes dommed by a paki gay credit card scammer lol.>?ali akbar drug nick around for #STOPTHESTEAL and nick stood behind him like a kid behind his momali akbar is a literal gay MAP who got arrested for stealing credit cards lol. nick fuentes fucking sucks. but hes relatable to alot of people on pol so he stays around.',
#      'name': 'Anonymous',
#      'no': 339658457,
#      'now': '09/18/21(Sat)04:21:26',
#      'resto': 339654944,
#      'time': 1631953286,
#      'archivedon': 1631972405.125545},
#     'sort': [1631938886000]},
#    {'_index': 'smat-4chan-data-000001',
#     '_type': '_doc',
#     '_id': 'b_863119780',
#     '_score': None,
#     '_source': {'board': 'b',
#      'chan': 1,
#      'id': 20000863119780,
#      'urls': ['https://i.4cdn.org/b/1631692247962.jpg'],
#      'v': 1.7,
#      'com': '<a href="#p863119555" class="quotelink">&gt;&gt;863119555</a><br>IF YOU COUNT THE LEGAL VOTES I EASILY WIN<br>#StopTheSteal #Caitlyn4California',
#      'ext': '.jpg',
#      'filename': 'jenner-intro-1526047822',
#      'fsize': 50148,
#      'h': 439,
#      'htmlparsedcom': '>>863119555IF YOU COUNT THE LEGAL VOTES I EASILY WIN#StopTheSteal #Caitlyn4California',
#      'md5': 'AuOIU+6pavTKhKPXbej+8g==',
#      'name': 'Anonymous',
#      'no': 863119780,
#      'now': '09/15/21(Wed)03:50:47',
#      'resto': 863119555,
#      'tim': 1631692247962,
#      'time': 1631692247,
#      'tnh': 70,
#      'tnw': 125,
#      'w': 780,
#      'archivedon': 1631692314.058684},
#     'sort': [1631677847000]},
#    {'_index': 'smat-4chan-data-000001',
#     '_type': '_doc',
#     '_id': 'pol_339135260',
#     '_score': None,
#     '_ignored': ['htmlparsedcom.keyword', 'com.keyword'],
#     '_source': {'board': 'pol',
#      'chan': 1,
#      'id': 'YNF6pBIC',
#      'urls': [],
#      'v': 1.7,
#      'com': 'Tfw I used to be a lefty (cringe!) but now I love my liberty and miss President Trump! #StopTheSteal I’m drinking a beer and smoking some herb right now I love freedom!!!!! Make the south great again <br><br>I also kind of like the alt right meme who wants to put our differences aside and make the alt right great again to fight the antifa larpers and insane people',
#      'country': 'US',
#      'countryname': 'United States',
#      'htmlparsedcom': 'Tfw I used to be a lefty (cringe!) but now I love my liberty and miss President Trump! #StopTheSteal I’m drinking a beer and smoking some herb right now I love freedom!!!!! Make the south great again I also kind of like the alt right meme who wants to put our differences aside and make the alt right great again to fight the antifa larpers and insane people',
#      'name': 'Silba',
#      'no': 339135260,
#      'now': '09/14/21(Tue)17:41:18',
#      'resto': 339119638,
#      'time': 1631655678,
#      'trip': '!!T2UdrWkLSWB',
#      'archivedon': 1631655842.279087},
#     'sort': [1631641278000]},
#    {'_index': 'smat-4chan-data-000001',
#     '_type': '_doc',
#     '_id': 'int_151673243',
#     '_score': None,
#     '_source': {'board': 'int',
#      'chan': 1,
#      'id': 500000151673243,
#      'urls': [],
#      'v': 1.7,
#      'com': 'The noble effort to #StopTheSteal?',
#      'country': 'CA',
#      'countryname': 'Canada',
#      'htmlparsedcom': 'The noble effort to #StopTheSteal?',
#      'name': 'Anonymous',
#      'no': 151673243,
#      'now': '09/11/21(Sat)21:50:58',
#      'resto': 151672761,
#      'time': 1631411458,
#      'archivedon': 1631411544.229356},
#     'sort': [1631397058000]},
#    {'_index': 'smat-4chan-data-000001',
#     '_type': '_doc',
#     '_id': 'news_923880',
#     '_score': None,
#     '_ignored': ['com.keyword'],
#     '_source': {'board': 'news',
#      'chan': 1,
#      'id': 560000923880,
#      'urls': [],
#      'v': 1.7,
#      'com': '<a href="#p923577" class="quotelink">&gt;&gt;923577</a><br>You also can&#039;t sieg heil like you can in America, fucking Germans are Nazis man; fucking liberal media agenda taking our borders. #2ndAmendmentRights #stopthesteal #IvermectinIsExtraterrestrialCum',
#      'htmlparsedcom': ">>923577You also can't sieg heil like you can in America, fucking Germans are Nazis man; fucking liberal media agenda taking our borders. #2ndAmendmentRights #stopthesteal #IvermectinIsExtraterrestrialCum",
#      'name': 'Anonymous',
#      'no': 923880,
#      'now': '09/05/21(Sun)21:07:22',
#      'resto': 917662,
#      'time': 1630890442,
#      'archivedon': 1631330211.879702},
#     'sort': [1630876042000]}]}}

# %%
# The data's in ['hits']['hits']. Check how much there is
print("{} data entries in here".format(len(jsondata['hits']['hits'])))
# Out:
# 9 data entries in here

# %%
# read the data in using library pandas.  
# Notice how this get the top-level items, not the data rows
df = pd.read_json(jsonfile)
df
# Out:
#            created_key    content_key  took  timed_out  _shards  \
# total              now  htmlparsedcom  1108      False      2.0
# successful         now  htmlparsedcom  1108      False      2.0
# skipped            now  htmlparsedcom  1108      False      0.0
# failed             now  htmlparsedcom  1108      False      0.0
# max_score          now  htmlparsedcom  1108      False      NaN
# hits               now  htmlparsedcom  1108      False      NaN
#
#                                                          hits
# total                          {'value': 9, 'relation': 'eq'}
# successful                                                NaN
# skipped                                                   NaN
# failed                                                    NaN
# max_score                                                None
# hits        [{'_index': 'smat-4chan-data-000002', '_type':...

# %%
# function json_normalize to the rescue!  
# Read data in using the json library, then convert just the data array
dfdata = pd.json_normalize(jsondata['hits']['hits'])
dfdata
# Out:
#                    _index _type            _id _score  \
# 0  smat-4chan-data-000002  _doc    news_941273   None
# 1  smat-4chan-data-000002  _doc   tv_157006540   None
# 2  smat-4chan-data-000001  _doc   sp_113574173   None
# 3  smat-4chan-data-000001  _doc  pol_340727489   None
# 4  smat-4chan-data-000001  _doc  pol_339658457   None
# 5  smat-4chan-data-000001  _doc    b_863119780   None
# 6  smat-4chan-data-000001  _doc  pol_339135260   None
# 7  smat-4chan-data-000001  _doc  int_151673243   None
# 8  smat-4chan-data-000001  _doc    news_923880   None
#
#                                _ignored             sort _source.board  \
# 0  [htmlparsedcom.keyword, com.keyword]  [1633631757000]          news
# 1                                   NaN  [1633002982000]            tv
# 2                                   NaN  [1632556011000]            sp
# 3                                   NaN  [1632512927000]           pol
# 4  [htmlparsedcom.keyword, com.keyword]  [1631938886000]           pol
# 5                                   NaN  [1631677847000]             b
# 6  [htmlparsedcom.keyword, com.keyword]  [1631641278000]           pol
# 7                                   NaN  [1631397058000]           int
# 8                         [com.keyword]  [1630876042000]          news
#
#    _source.chan       _source.id                                _source.urls  \
# 0             1     560000941273                                          []
# 1             1  670000157006540                                          []
# 2             1  630000113574173                                          []
# 3             1         agF8ZtES  [https://i.4cdn.org/pol/1632527327341.jpg]
# 4             1         xs/Q8Mvw                                          []
# 5             1   20000863119780    [https://i.4cdn.org/b/1631692247962.jpg]
# 6             1         YNF6pBIC                                          []
# 7             1  500000151673243                                          []
# 8             1     560000923880                                          []
#
#    ...         _source.filename _source.fsize _source.h _source.mimg  \
# 0  ...                      NaN           NaN       NaN          NaN
# 1  ...                      NaN           NaN       NaN          NaN
# 2  ...                      NaN           NaN       NaN          NaN
# 3  ...            1632527319122      113267.0    1280.0          1.0
# 4  ...                      NaN           NaN       NaN          NaN
# 5  ...  jenner-intro-1526047822       50148.0     439.0          NaN
# 6  ...                      NaN           NaN       NaN          NaN
# 7  ...                      NaN           NaN       NaN          NaN
# 8  ...                      NaN           NaN       NaN          NaN
#
#                 _source.md5   _source.tim  _source.tnh  _source.tnw  \
# 0                       NaN           NaN          NaN          NaN
# 1                       NaN           NaN          NaN          NaN
# 2                       NaN           NaN          NaN          NaN
# 3  iiW4jL9s7LJhBJmwjYgttQ==  1.632527e+12        125.0         57.0
# 4                       NaN           NaN          NaN          NaN
# 5  AuOIU+6pavTKhKPXbej+8g==  1.631692e+12         70.0        125.0
# 6                       NaN           NaN          NaN          NaN
# 7                       NaN           NaN          NaN          NaN
# 8                       NaN           NaN          NaN          NaN
#
#    _source.w   _source.trip
# 0        NaN            NaN
# 1        NaN            NaN
# 2        NaN            NaN
# 3      591.0            NaN
# 4        NaN            NaN
# 5      780.0            NaN
# 6        NaN  !!T2UdrWkLSWB
# 7        NaN            NaN
# 8        NaN            NaN
#
# [9 rows x 32 columns]

# %%
# Feeling cute. Dumping dataset to a CSV file so we can use it elsewhere
dfdata.to_csv(jsonroot + '.csv', index=False)
