# %% [markdown]
# # Text dataset features

# %%
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
fin = 'data/andypateltwitter/20211019172839_stopthesteal/20211019172839_stopthesteal_tweets.json'
ftweets = open('data/andypateltwitter/20211019172839_stopthesteal/20211019172839_stopthesteal_tweets.json')
tweetdata = json.load(ftweets)
ftweets.close()
tweetdata
# Out:
# {'https://twitter.com/Theon_Orbis/status/1450571068473626629': 'RT @Tam_Resist: US sanctioned Deripaska for *meddling in the 2016 election-Tfg lifted those sanctions as 2016 was the precursor of #StopThe…',
#  'https://twitter.com/smimsitis/status/1450565418343559170': 'RT @ddanpereira: The #FBI has raided the home of Oleg Deripaska, Russian Billionaire &amp; #Putin ally, in DC! #PaulManafort owed a lot of mone…',
#  'https://twitter.com/ElkeHollings/status/1450544622527156227': 'RT @ddanpereira: The #FBI has raided the home of Oleg Deripaska, Russian Billionaire &amp; #Putin ally, in DC! #PaulManafort owed a lot of mone…',
#  'https://twitter.com/PumpkinBlend/status/1450543853208018952': '@kitsumitsu46 @ashleyloveslmg wow what happened to my vote #stopthesteal',
#  'https://twitter.com/nola_chwica/status/1450543275937435649': 'RT @ZhiZhuWeb: "Republicans’ #StopTheSteal campaign ... is also a massive and devastatingly effective deployment of Russian-style informati…',
# ...

# %%
df = pd.DataFrame([tweetdata]).transpose().reset_index()
df
# Out:
#                                                   index  \
# 0     https://twitter.com/Theon_Orbis/status/1450571...
# 1     https://twitter.com/smimsitis/status/145056541...
# 2     https://twitter.com/ElkeHollings/status/145054...
# 3     https://twitter.com/PumpkinBlend/status/145054...
# 4     https://twitter.com/nola_chwica/status/1450543...
# ...                                                 ...
# 2093  https://twitter.com/golfnutallways/status/1447...
# 2094  https://twitter.com/KW07038391/status/14473850...
# 2095  https://twitter.com/Chi2soCal2LV/status/144738...
# 2096  https://twitter.com/Lola36405979/status/144738...
# 2097  https://twitter.com/wb1967borders/status/14473...
#
#                                                       0
# 0     RT @Tam_Resist: US sanctioned Deripaska for *m...
# 1     RT @ddanpereira: The #FBI has raided the home ...
# 2     RT @ddanpereira: The #FBI has raided the home ...
# 3     @kitsumitsu46 @ashleyloveslmg wow what happene...
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vect = CountVectorizer(stop_words='english')
word_counts = count_vect.fit_transform(df[0])

print('{}'.format(word_counts))
print('{}'.format(count_vect.vocabulary_))
# Out:
#   (0, 2657)	1
#   (0, 2983)	1
#   (0, 2683)	1
#   (0, 827)	1
#   (0, 1960)	1
#   (0, 28)	2
#   (0, 959)	1
#   (0, 3016)	1
#   (0, 1814)	1
#   (0, 2684)	1
#   (0, 2375)	1
#   (0, 2906)	1
#   (1, 2657)	1
#   (1, 827)	1
#   (1, 773)	1
#   (1, 1105)	1
#   (1, 2486)	1
#   (1, 1429)	1
#   (1, 2192)	1
#   (1, 2669)	1
#   (1, 391)	1
#   (1, 208)	1
#   (1, 2451)	1
#   (1, 187)	1
#   (1, 772)	1
#   :	:
#   (2094, 2915)	1
#   (2094, 1453)	1
#   (2094, 2109)	1
#   (2094, 1248)	1
#   (2094, 798)	1
#   (2094, 1734)	1
#   (2095, 2657)	1
#   (2095, 959)	1
#   (2095, 2915)	1
#   (2095, 1453)	1
#   (2095, 2109)	1
#   (2095, 1248)	1
#   (2095, 798)	1
#   (2095, 1734)	1
#   (2096, 2915)	1
#   (2096, 1453)	1
#   (2096, 1117)	1
#   (2097, 2657)	1
#   (2097, 959)	1
#   (2097, 2915)	1
#   (2097, 1453)	1
#   (2097, 2109)	1
#   (2097, 1248)	1
#   (2097, 798)	1
#   (2097, 1734)	1
# ...

# %%
# UNgodly hack to see words
df = pd.DataFrame(word_counts.A, columns=count_vect.get_feature_names()).transpose()
pd.DataFrame(df.transpose().sum()).sort_values(0, ascending=False)[:30]
# Out:
#                  0
# rt            1659
# election      1181
# gbrough10     1059
# stopthesteal   873
# 2020           791
# states         750
# 50             749
# forensic       746
# national       746
# presidential   746
# stoptheste     743
# kimberly       743
# audits         743
# asking         743
# guilfoyle      743
# https          720
# demand         349
# new            327
# kx8kux0atk     317
# trump          245
# amp            219
# tam_resist     192
# gop            105
# steal           98
# did             89
# 2024            88
# michigan        81
# like            71
# laying          71
# groundwork      71

# %%
count_vectn = CountVectorizer(ngram_range =(2, 2))
word_countsn = count_vectn.fit_transform(df[0])

df_n = pd.DataFrame(word_countsn.A, columns=count_vectn.get_feature_names()).transpose()
pd.DataFrame(df_n.transpose().sum()).sort_values(0, ascending=False)[:30]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-50370b29ec19> in <module>
#       1 count_vectn = CountVectorizer(ngram_range =(2, 2))
# ----> 2 word_countsn = count_vectn.fit_transform(df[0])
#       3
#       4 df_n = pd.DataFrame(word_countsn.A, columns=count_vectn.get_feature_names()).transpose()
#       5 pd.DataFrame(df_n.transpose().sum()).sort_values(0, ascending=False)[:30]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1196         max_features = self.max_features
#    1197
# -> 1198         vocabulary, X = self._count_vocab(raw_documents,
#    1199                                           self.fixed_vocabulary_)
#    1200
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
# ...

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tf_transformer = TfidfTransformer(use_idf=False)
tf_features = tf_transformer.fit_transform(word_counts)
print('{}'.format(tf_features))
# Out:
#   (0, 28)	0.5163977794943222
#   (0, 827)	0.2581988897471611
#   (0, 959)	0.2581988897471611
#   (0, 1814)	0.2581988897471611
#   (0, 1960)	0.2581988897471611
#   (0, 2375)	0.2581988897471611
#   (0, 2657)	0.2581988897471611
#   (0, 2683)	0.2581988897471611
#   (0, 2684)	0.2581988897471611
#   (0, 2906)	0.2581988897471611
#   (0, 2983)	0.2581988897471611
#   (0, 3016)	0.2581988897471611
#   (1, 187)	0.24253562503633297
#   (1, 208)	0.24253562503633297
#   (1, 391)	0.24253562503633297
#   (1, 772)	0.24253562503633297
#   (1, 773)	0.24253562503633297
#   (1, 827)	0.24253562503633297
#   (1, 1105)	0.24253562503633297
#   (1, 1429)	0.24253562503633297
#   (1, 1864)	0.24253562503633297
#   (1, 2030)	0.24253562503633297
#   (1, 2192)	0.24253562503633297
#   (1, 2226)	0.24253562503633297
#   (1, 2274)	0.24253562503633297
#   :	:
#   (2094, 1248)	0.35355339059327373
#   (2094, 1453)	0.35355339059327373
#   (2094, 1734)	0.35355339059327373
#   (2094, 2109)	0.35355339059327373
# ...
